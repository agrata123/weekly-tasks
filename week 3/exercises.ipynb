# %%
1.) What is the data-type of the result when evaluating comparison (relational) expressions such
 as < and >?

 ans. Boolean

# %%
2.) For each of the following expressions write the result of their evaluation.

a) 100 < 101 
Ans: True

b) 100 > 99 
Ans: True

c)100 >= 100 
Ans: True

d) 100 != 100 
Ans: False

e)"abc" < "xyz" 
Ans: True

f) "abc" < "XYZ" 
Ans: False

g) "100" == 100 
Ans: False

h) 10 > 20 and 10 >= 10 
Ans: False

i) 10 > 30 > 20 
Ans: False

i) 40 < 20 or 20 < 30 
Ans: True

J) not True
Ans: False

# %%
3) colours = [ "Blue", "Black", "Orange" ]
print("The colour black is in the list : ", "Black" in colours)

Ans: The colour black is in the list :  True
        

b)print("The colour orange is in the list : ", "orange" in colours)

Ans:The colour orange is in the list :  True

# %%
4)Which of the following concepts does the Python ‘if’ statement support?
Sequence, Selection or Iteration?

Ans: Selection

# %%
5) What would be the output shown following the execution of the following Python statements?

num1 = 100
num2 = 10
if num1 % num2 == 0:
    print("num1 is divisible by num2")
else:
    print("num1 is not divisible by num2")

Ans: num1 is divisible by num2

# %%
6) What would be the output shown following the execution of the following Python statements?

num1 = 99
num2 = 70
if num1 < num2:
print("num1 is less than num2")
elif num1 > num2:
print("num1 is greater than num2")
else:
print("num1 is equal to num2")

Ans: num1 is greater than num2

# %%
7)What is the name given to the following type of Python operator shown below?

a) lowest = x if x < y else y
Ans: Ternary operator
    
b) And, what value would be assigned to the variable ‘lowest’ when ‘x’ was equal to 10 and
‘y’ was equal to 5?
Ans: 5

# %%
 
#8) 
num =  int(input("Enter a number between 1 and 10 : "))
if num in range (1,11):
    print("in range")
else:
    print("not in range")

# %%
#9)
x = int(input("enter the first value:"))
y = int(input("enter the second value:"))
if x > y:
    print(" The value 'x' is larger than the value 'y'")
elif y > x:
    print("The value 'y' is larger than the value 'x'")
# Out:
# The value 'y' is larger than the value 'x'

# %%
12)Examine the output generated by the above program. Is the displayed text entirely accurate
 in all cases? If not Why?

Ans: if x and y are equal

# %%
13)Within the answer box below write a small Python program that asks the user to enter two
 values.
 Store these values in two variables then output a message displaying the result of dividing
 the first value by the second value.
 Include code that prevents a run-time error being reported when the user inputs a value of '0'
 for the second input. Hint: use an ‘if’ statement
 If a '0' value is input, print a message saying "division by 0 is not possible".

# %%
value_1 = int(input("please enter the first value:"))
value_2= int(input("please enter the second value:"))
if value_2 != 0:
  print(x/y)
else:
    value_2 == 0
    print("division by 0 is not possible")
# Out:
# 0.9523809523809523

# %%
14) Which of the following concepts does the Python while statement support?
 Sequence, Selection or Iteration?

Ans: Iteration

# %%
#15) What would be the output shown following the execution of the following Python statements?
num = 5
while num > 0:
  print(num)
  num -= 1
# Out:
# 5
# 4
# 3
# 2
# 1

# %%
#16) Write a small Python program that prints your name to the screen 100 times, then enter the
 #program into the answer box below. Hint: use a ‘while’ loop.
 
n = 1
while n <=100:
    print("agrata")
    n += 1
# Out:
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata
# agrata

# %%
1#7)What would be the output shown following the execution of the following Python statements?
vals = ["A", "B", "C", "D"]
for letter in vals:
  print(letter)
# Out:
# A
# B
# C
# D

# %%
#18)What would be the output shown following the execution of each of the following Python
#statements?

for num in range(5):
 print(num)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for num in range(10,16):
 print(num)
# Out:
# 10
# 11
# 12
# 13
# 14
# 15

# %%
for num in range(0,10,-1):
   print(num)

# %%
19) Enter and execute the python code shown below, then show the exact output into the
 answer box.

# %%
for x in range(1,10):
     for y in range (1,x):
          print("*")
     print()

# %%
20)  What is the term used to refer to code blocks that appear inside other code blocks as in the
 above program?

Ans: nested code blocks
